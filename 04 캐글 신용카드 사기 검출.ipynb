# %% [markdown]
# ### 데이터 일차 가공

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
card_df = pd.read_csv('./data/credit/creditcard.csv')
card_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
card_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# 인자로 입력받은 DataFrame을 복사한 뒤 'Time' 삭제 반환
def get_preprocessed_df(df=None):
    df_copy=df.copy()
    df_copy.drop('Time',axis=1,inplace=True)
    return df_copy

# %%
# 학습/테스트 데이터(답) 분할 함수
from sklearn.model_selection import train_test_split

def get_train_test_dataset(df=None):
    # parameter => df : 원본 데이터프레임
    df_copy=get_preprocessed_df(df)
    # DataFrame에서 맨 마직막 컬럼이 레이블(답),나머지는 데이터
    X_features=df_copy.iloc[:,:-1]
    y_label = df_copy.iloc[:,-1]
    
    #학습/테스트 데이터 분리 : 레이블이 동일분포로 분리
    X_train,X_test,y_train,y_test=\
    train_test_split(
        X_features
        ,y_label
        ,test_size=0.3
        ,random_state=0
        ,stratify=y_label # 레이블(0,1)이 동일분포로 분리
    )
    return X_train,X_test,y_train,y_test

# %%
X_train,X_test,y_train,y_test=\
get_train_test_dataset(card_df)

# %%
y_train.shape # 학습데이터 전체 답의 개수
# Out:
# (199364,)

# %%
y_train.value_counts() # 클래스별 개수
# Out:
# 0    199020
# 1       344
# Name: Class, dtype: int64

# %%
# 학습데이터의 레이블의 비율
y_train.value_counts()/y_train.shape[0] *100
# Out:
# 0    99.827451
# 1     0.172549
# Name: Class, dtype: float64

# %%
# 테스트데이터의 레이블의 비율
y_test.value_counts()/y_test.shape[0] *100
# Out:
# 0    99.826785
# 1     0.173215
# Name: Class, dtype: float64

# %%
# 검증하는 함수(오차행렬,정확도,정밀도,재현률,AUC)
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score

def get_clf_eval(y_test,pred):
    confusion=confusion_matrix(y_test,pred)
    accu=accuracy_score(y_test,pred)
    prec=precision_score(y_test,pred)
    recall=recall_score(y_test,pred)
    
    auc=roc_auc_score(y_test,pred)
    print('오차행렬')
    print(confusion)
    
    out_str='정확도 : {0:.4f},정밀도 : {1:.4f},재현률 : {2:.4f},AUC : {3:.4f}'
    print(out_str.format(accu,prec,recall,auc))

# %%
# LogisticRegression : 분류
from sklearn.linear_model import LogisticRegression

lr_clf=LogisticRegression()
lr_clf.fit(X_train,y_train)
lr_pred=lr_clf.predict(X_test)
get_clf_eval(y_test,lr_pred)
# Out:
# 오차행렬
# [[85282    13]
#  [   57    91]]
# 정확도 : 0.9992,정밀도 : 0.8750,재현률 : 0.6149,AUC : 0.8074

# %%
# model : 학습을 진행할 알고리즘
# 학습데이터,테스트데이터,레이블들
def get_model_train_eval(model,ftr_train=None,ftr_test=None,tgt_train=None,tgt_test=None):
    model.fit(ftr_train,tgt_train) #학습
    pred = model.predict(ftr_test) #예측값
    get_clf_eval(tgt_test,pred) # 성능 평가

# %%
# lightGBM 사용
from lightgbm import LGBMClassifier

lgbm_clf=LGBMClassifier(
    n_estimators=1000
    ,num_leaves=64 # 결정노드 64
    ,n_jobs=-1 # 모든 코어 사용 =병렬처리
    ,boost_from_average=False #재현율과 AUC성능 높이기 위해
)
get_model_train_eval(lgbm_clf
                     ,ftr_train=X_train
                    ,ftr_test=X_test
                    ,tgt_train=y_train
                    ,tgt_test=y_test)
# Out:
# 오차행렬
# [[85290     5]
#  [   36   112]]
# 정확도 : 0.9995,정밀도 : 0.9573,재현률 : 0.7568,AUC : 0.8783

# %% [markdown]
# #### 데이터 분포도 변환 후 모델 학습/예측/평가

# %%
card_df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %%
# Amount 분포 시각화
import seaborn as sns

plt.figure(figsize=(8,4))
plt.xticks(range(0,26000,1000),rotation=60) # x축의 틱 설정
sns.distplot(card_df['Amount'])

# %%
# 함수 수정 => StandardScaler
# 인자로 입력받은 DataFrame을 복사한 뒤 'Time' 삭제 반환
from sklearn.preprocessing import StandardScaler

def get_preprocessed_df(df=None):
    df_copy=df.copy()
    scaler=StandardScaler()
    amount_n = scaler.fit_transform(
        df_copy['Amount'].values.reshape(-1,1) #ndarray 변환,2차원 배열
    )
#     df_copy['Amount_Scaled']=amount_n
    df_copy.insert(0,'Amount_Scaled',amount_n)
    df_copy.drop(['Time','Amount'],axis=1,inplace=True)
    return df_copy

# %%
# Scaler 사용 데이터를 시각화 -> 분포
df_copy =get_preprocessed_df(card_df)
df_copy.describe()
# Out:
#        Amount_Scaled            V1            V2            V3            V4  \
# count   2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    2.913952e-17  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     1.000002e+00  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min    -3.532294e-01 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%    -3.308401e-01 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%    -2.652715e-01  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    -4.471707e-02  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max     1.023622e+02  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %%
plt.figure(figsize=(8,4))
plt.xticks(range(-4,2,1),rotation=60) # x축의 틱 설정
sns.distplot(df_copy['Amount_Scaled'])

# %%
# Standard Scaled data -> LogisticReg,LightGBM
X_train,X_test,y_train,y_test =\
get_train_test_dataset(card_df)
print('### 로지스틱 회귀 예측 성능')
lr_clf = LogisticRegression()
get_model_train_eval(
    lr_clf
    ,ftr_train=X_train
    ,ftr_test=X_test
    ,tgt_train=y_train
    ,tgt_test=y_test
)
# Out:
# ### 로지스틱 회귀 예측 성능
# 오차행렬
# [[85281    14]
#  [   58    90]]
# 정확도 : 0.9992,정밀도 : 0.8654,재현률 : 0.6081,AUC : 0.8040

# %%
print('### LightGBM 예측 서능 ###')
lgbm_clf=LGBMClassifier(
    n_estimators=1000
    ,num_leaves=64 # 결정노드 64
    ,n_jobs=-1 # 모든 코어 사용 =병렬처리
    ,boost_from_average=False #재현율과 AUC성능 높이기 위해
)
get_model_train_eval(lgbm_clf
                     ,ftr_train=X_train
                    ,ftr_test=X_test
                    ,tgt_train=y_train
                    ,tgt_test=y_test)
# Out:
# ### LightGBM 예측 서능 ###
# 오차행렬
# [[85290     5]
#  [   37   111]]
# 정확도 : 0.9995,정밀도 : 0.9569,재현률 : 0.7500,AUC : 0.8750

# %%
#   amount_n = np.log1p(df_copy['Amount']) => 로그 변환
def get_preprocessed_df(df=None):
    df_copy=df.copy()
    amount_n = np.log1p(df_copy['Amount'])
#     df_copy['Amount_Scaled']=amount_n
    df_copy.insert(0,'Amount_Scaled',amount_n)
    df_copy.drop(['Time','Amount'],axis=1,inplace=True)
    return df_copy

# %%
df_copy =get_preprocessed_df(card_df)
df_copy.describe()
# Out:
#        Amount_Scaled            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean        3.152188  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std         1.656648  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%         1.887070 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%         3.135494  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%         4.358822  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max        10.153941  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %%
plt.figure(figsize=(8,4))
plt.xticks(range(0,11,1),rotation=60) # x축의 틱 설정
sns.distplot(df_copy['Amount_Scaled'])

# %%
X_train,X_test,y_train,y_test =\
get_train_test_dataset(card_df)
print('### 로지스틱 회귀 예측 성능')
lr_clf = LogisticRegression()
get_model_train_eval(
    lr_clf
    ,ftr_train=X_train
    ,ftr_test=X_test
    ,tgt_train=y_train
    ,tgt_test=y_test
)
# 정확도 : 0.9992,정밀도 : 0.8654,재현률 : 0.6081,AUC : 0.8040
# Out:
# ### 로지스틱 회귀 예측 성능
# 오차행렬
# [[85283    12]
#  [   59    89]]
# 정확도 : 0.9992,정밀도 : 0.8812,재현률 : 0.6014,AUC : 0.8006

# %%
print('### LightGBM 예측 서능 ###')
lgbm_clf=LGBMClassifier(
    n_estimators=1000
    ,num_leaves=64 # 결정노드 64
    ,n_jobs=-1 # 모든 코어 사용 =병렬처리
    ,boost_from_average=False #재현율과 AUC성능 높이기 위해
)
get_model_train_eval(lgbm_clf
                     ,ftr_train=X_train
                    ,ftr_test=X_test
                    ,tgt_train=y_train
                    ,tgt_test=y_test)

#정확도 : 0.9995,정밀도 : 0.9569,재현률 : 0.7500,AUC : 0.8750
# Out:
# ### LightGBM 예측 서능 ###
# 오차행렬
# [[85290     5]
#  [   35   113]]
# 정확도 : 0.9995,정밀도 : 0.9576,재현률 : 0.7635,AUC : 0.8817

# %% [markdown]
# ### 이상치 데이터 제거 후 모델 학습/예측/평가

# %%
# heatmap으로 상관관계 추출
import seaborn as sns

# 각 변수별 상관계수(값) 구한다.
# 계수값 : -1 <=a<=1
# a =0 관계없다
corr = card_df.corr()
corr
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.697350e-17 -1.424390e-15  1.755316e-17
# V2     -0.010593  4.697350e-17  1.000000e+00  2.512175e-16 -1.126388e-16
# V3     -0.419618 -1.424390e-15  2.512175e-16  1.000000e+00 -3.416910e-16
# V4     -0.105260  1.755316e-17 -1.126388e-16 -3.416910e-16  1.000000e+00
# V5      0.173072  6.391162e-17 -2.039868e-16 -1.436514e-15 -1.940929e-15
# V6     -0.063016  2.398071e-16  5.024680e-16  1.431581e-15 -2.712659e-16
# V7      0.084714  1.991550e-15  3.966486e-16  2.168574e-15  1.556330e-16
# V8     -0.036949 -9.490675e-17 -4.413984e-17  3.433113e-16  5.195643e-16
# V9     -0.008660  2.169581e-16 -5.728718e-17 -4.233770e-16  3.859585e-16
# V10     0.030617  7.433820e-17 -4.782388e-16  6.289267e-16  6.055490e-16
# V11    -0.247689  2.438580e-16  9.468995e-16 -5.501758e-17 -2.083600e-16
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(corr,cmap='RdBu')

# %%
# 이상치 인덱스 검출 함수
def get_outlier(df=None,col=None,weight=1.5):
    fraud=df[df['Class']==1][col]
    q_25 =np.percentile(fraud.values,25)
    q_75 =np.percentile(fraud.values,75)
    iqr = q_75-q_25 # 범위
    iqr_weight=iqr*weight
    low_val = q_25-iqr_weight #최소값
    high_val=q_75+iqr_weight #최대값
    out_index =fraud[(fraud<low_val)|(fraud>high_val)].index
    return out_index

# %%
out_index_14=get_outlier(df=card_df,col='V14')
print('이상치 데이터 인덱스 : ',out_index)
# Out:
# 이상치 데이터 인덱스 :  Int64Index([], dtype='int64')

# %%
out_index_17=get_outlier(df=card_df,col='V17')
print('이상치 데이터 인덱스 : ',out_index)
# Out:
# 이상치 데이터 인덱스 :  Int64Index([], dtype='int64')

# %%
def get_preprocessed_df(df=None):
    df_copy=df.copy()
    # Amount 처리
    amount_n = np.log1p(df_copy['Amount'])
#     df_copy['Amount_Scaled']=amount_n
    df_copy.insert(0,'Amount_Scaled',amount_n)
    df_copy.drop(['Time','Amount'],axis=1,inplace=True)
    # 이상치 처리 코드
    out_index=get_outlier(df=df_copy,col='V14')
    df_copy.drop(out_index,axis=0,inplace=True)
    return df_copy

# %%
X_train,X_test,y_train,y_test =\
get_train_test_dataset(card_df)
print('### 로지스틱 회귀 예측 성능')
lr_clf = LogisticRegression()
get_model_train_eval(
    lr_clf
    ,ftr_train=X_train
    ,ftr_test=X_test
    ,tgt_train=y_train
    ,tgt_test=y_test
)
# 정확도 : 0.9992,정밀도 : 0.8812,재현률 : 0.6014,AUC : 0.8006
# Out:
# ### 로지스틱 회귀 예측 성능
# 오차행렬
# [[85281    14]
#  [   48    98]]
# 정확도 : 0.9993,정밀도 : 0.8750,재현률 : 0.6712,AUC : 0.8355

# %%
print('### LightGBM 예측 서능 ###')
lgbm_clf=LGBMClassifier(
    n_estimators=1000
    ,num_leaves=64 # 결정노드 64
    ,n_jobs=-1 # 모든 코어 사용 =병렬처리
    ,boost_from_average=False #재현율과 AUC성능 높이기 위해
)
get_model_train_eval(lgbm_clf
                     ,ftr_train=X_train
                    ,ftr_test=X_test
                    ,tgt_train=y_train
                    ,tgt_test=y_test)
# 정확도 : 0.9995,정밀도 : 0.9576,재현률 : 0.7635,AUC : 0.8817
# Out:
# ### LightGBM 예측 서능 ###
# 오차행렬
# [[85290     5]
#  [   25   121]]
# 정확도 : 0.9996,정밀도 : 0.9603,재현률 : 0.8288,AUC : 0.9144

# %% [markdown]
# ### 3.오버 샘플링 적용 후 모델 학습/예측/평가

# %%
from imblearn.over_sampling import SMOTE

# %%
smote =SMOTE(random_state=0)
# 학습데이터(답) 들어가서 오버 되어서 나온다 
# 오버된 학습데이터,오버된 학습데이터 답
X_train_over,y_train_over=\
smote.fit_sample(X_train,y_train)

# %%
# 원래 학습데이터와 레이블의 shape
X_train.shape,y_train.shape
# Out:
# ((199362, 29), (199362,))

# %%
y_train.value_counts()
# Out:
# 0    199020
# 1       342
# Name: Class, dtype: int64

# %%
X_train_over.shape,y_train_over.shape
# Out:
# ((398040, 29), (398040,))

# %%
X_train,X_test,y_train,y_test =\
get_train_test_dataset(card_df)
print('### 로지스틱 회귀 예측 성능')
lr_clf = LogisticRegression()
get_model_train_eval(
    lr_clf
    ,ftr_train=X_train_over
    ,ftr_test=X_test
    ,tgt_train=y_train_over
    ,tgt_test=y_test
)
# 정확도 : 0.9993,정밀도 : 0.8750,재현률 : 0.6712,AUC : 0.8355
# Out:
# ### 로지스틱 회귀 예측 성능
# 오차행렬
# [[82937  2358]
#  [   11   135]]
# 정확도 : 0.9723,정밀도 : 0.0542,재현률 : 0.9247,AUC : 0.9485

# %%
print('### LightGBM 예측 서능 ###')
lgbm_clf=LGBMClassifier(
    n_estimators=1000
    ,num_leaves=64 # 결정노드 64
    ,n_jobs=-1 # 모든 코어 사용 =병렬처리
    ,boost_from_average=False #재현율과 AUC성능 높이기 위해
)
get_model_train_eval(lgbm_clf
                     ,ftr_train=X_train_over
                    ,ftr_test=X_test
                    ,tgt_train=y_train_over
                    ,tgt_test=y_test)
# 정확도 : 0.9996,정밀도 : 0.9603,재현률 : 0.8288,AUC : 0.9144
# Out:
# ### LightGBM 예측 서능 ###
# 오차행렬
# [[85283    12]
#  [   22   124]]
# 정확도 : 0.9996,정밀도 : 0.9118,재현률 : 0.8493,AUC : 0.9246

# %% [markdown]
# ### 데이터 전처리
# 1. standardScaler : 원래값을 정규분포 값으로 변환(분포변환x)
# 2. log1p : 분포변환
# 3. 이상치 처리
# 4. 오버 샘플링
#
# ### 머신러닝/딥러닝
# - 기본 작동방식 : 예측값(평균)과  원래값(평균)의 차이를 최소화 하는 방식으로 학습
# - 평균은 outlier에 민감하다
